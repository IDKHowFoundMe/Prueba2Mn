# %% [markdown]
# # Mínimos cuadrados
# ## Prueba 02
# Interpole los siguientes conjuntos de datos con la función correspondiente.

# %% [markdown]
# La ecuación de la línea es:
#
# $ y(x) = a_1 x + a_0 $
#
# Al realizar el proceso de mínimos cuadrados queda el siguiente sistema de ecuaciones:
#
#
# $( \sum_i (y_i - a_1 x_i - a_0) , \sum_i (y_i - a_1 x_i - a_0)x_i ) = 0$

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """

    # coeficiente del término independiente
    c_ind = sum(ys)

    # coeficiente del parámetro 1
    c_1 = sum(xs)

    # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        # coeficiente del parámetro 1
        c_1 += xi * xi

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_1, c_0, c_ind)

# %% [markdown]
# # Conjunto de datos de ejemplo

# %%
xs = [
    -5.0000,
    -3.8889,
    -2.7778,
    -1.6667,
    -0.5556,
    0.5556,
    1.6667,
    2.7778,
    3.8889,
    5.0000,
]
ys = [
    -12.7292,
    -7.5775,
    -7.7390,
    -4.1646,
    -4.5382,
    2.2048,
    4.3369,
    2.2227,
    9.0625,
    7.1860,
]

# %%
from src import ajustar_min_cuadrados  # no modificar esta función

pars = ajustar_min_cuadrados(xs, ys, gradiente=[der_parcial_0, der_parcial_1])
# Out:
# [01-08 13:46:26][INFO] 2026-01-08 13:46:26.985973
# [01-08 13:46:27][INFO] 2026-01-08 13:46:27.073989
# [01-08 13:46:27][INFO] Se ajustarán 2 parámetros.
# [01-08 13:46:27][INFO]
# [[101.8525926    0.         209.87476711]
#  [  0.          10.         -11.7356    ]]

# %%
import numpy as np
import matplotlib.pyplot as plt

m, b = ajustar_min_cuadrados(xs, ys, gradiente=[der_parcial_0, der_parcial_1])

x = np.linspace(-5, 5, 100)

y = [m * xi + b for xi in x]

plt.scatter(xs, ys, label="Datos")
plt.plot(x, y, color="red", label=r"$ y = a_1 x + a_0 $")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste por mínimos cuadrados para conjunto de datos de ejemplo")
plt.legend()
plt.show()
# Out:
# [01-08 13:46:29][INFO] Se ajustarán 2 parámetros.
# [01-08 13:46:29][INFO]
# [[101.8525926    0.         209.87476711]
#  [  0.          10.         -11.7356    ]]

# %% [markdown]
# ## Conjunto de datos 1

# %%
xs1 = [
    -5.0000,
    -3.8889,
    -2.7778,
    -1.6667,
    -0.5556,
    0.5556,
    1.6667,
    2.7778,
    3.8889,
    5.0000,
]
ys1 = [
    57.2441,
    33.0303,
    16.4817,
    7.0299,
    0.5498,
    0.7117,
    3.4185,
    12.1767,
    24.9167,
    44.2495,
]

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    
    # coeficiente del término independiente
    c_ind = sum(ys)

    # coeficiente del parámetro 1
    c_1 = sum(xs)

    # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        # coeficiente del parámetro 1
        c_1 += xi * xi

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_1, c_0, c_ind)

# %%
from src import ajustar_min_cuadrados  # no modificar esta función

pars = ajustar_min_cuadrados(xs1, ys1, gradiente=[der_parcial_0, der_parcial_1])
a,b= ajustar_min_cuadrados(xs1, ys1, gradiente=[der_parcial_0, der_parcial_1])
print(pars)
# Out:
# [01-08 13:46:35][INFO] Se ajustarán 2 parámetros.
# [01-08 13:46:35][INFO]
# [[ 101.8525926     0.         -114.41357678]
#  [   0.           10.          199.8089    ]]
# [01-08 13:46:35][INFO] Se ajustarán 2 parámetros.
# [01-08 13:46:35][INFO]
# [[ 101.8525926     0.         -114.41357678]
#  [   0.           10.          199.8089    ]]
# [np.float64(-1.1233251295755429), np.float64(19.98089)]

# %%
import numpy as np
import matplotlib.pyplot as plt

m, b = ajustar_min_cuadrados(xs, ys, gradiente=[der_parcial_0, der_parcial_1])

x = np.linspace(-5, 5, 100)

y = [m * xi + b for xi in x]

plt.scatter(xs1, ys1, label="Datos")
plt.plot(x, y, color="red", label=r"$ y = a_1 x + a_0 $")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste por mínimos cuadrados para conjunto de datos de ejemplo")
plt.legend()
plt.show()
# Out:
# [01-08 13:46:38][INFO] Se ajustarán 2 parámetros.
# [01-08 13:46:38][INFO]
# [[101.8525926    0.         209.87476711]
#  [  0.          10.         -11.7356    ]]

# %% [markdown]
# Interpole el conjunto de datos 1 usando la función cuadrática.

# %% [markdown]
# Cuadrada

# %%
xs1 = [
    -5.0000,
    -3.8889,
    -2.7778,
    -1.6667,
    -0.5556,
    0.5556,
    1.6667,
    2.7778,
    3.8889,
    5.0000,
]
ys1 = [
    57.2441,
    33.0303,
    16.4817,
    7.0299,
    0.5498,
    0.7117,
    3.4185,
    12.1767,
    24.9167,
    44.2495,
]

# Derivadas parciales para regresión lineal
# ####################################################################


def der_parcial_2(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    
    c_2= 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += yi

        c_2 += xi**2
        # coeficiente del parámetro 1
        c_1 += xi

     # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_2,c_1, c_0, c_ind)

def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float,float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    
    c_2= 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        c_2 += xi**3
        # coeficiente del parámetro 1
        c_1 += xi**2

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_2,c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float,float,float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    
    c_2= 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += (xi**2) * yi

        
        c_2 += xi**4
        # coeficiente del parámetro 1
        c_1 += xi**3

        # coeficiente del parámetro 0
        c_0 += xi**2

    return (c_2,c_1, c_0, c_ind)

# %%
from src import ajustar_min_cuadrados  # no modificar esta función

pars = ajustar_min_cuadrados(xs1, ys1, gradiente=[der_parcial_0, der_parcial_1,der_parcial_2,])
a,b,c= ajustar_min_cuadrados(xs1, ys1, gradiente=[der_parcial_0, der_parcial_1,der_parcial_2])
print(pars)
# Out:
# [01-08 13:46:47][INFO] Se ajustarán 3 parámetros.
# [01-08 13:46:47][INFO]
# [[ 1.01852593e+02  0.00000000e+00  1.00000000e+01  1.99808900e+02]
#  [ 0.00000000e+00  1.01852593e+02  0.00000000e+00 -1.14413577e+02]
#  [-2.27373675e-13  0.00000000e+00 -7.90113041e+01  5.04294087e+01]]
# [01-08 13:46:47][INFO]
# [[ 1.01852593e+02  0.00000000e+00  1.00000000e+01  1.99808900e+02]
#  [ 0.00000000e+00  1.01852593e+02  0.00000000e+00 -1.14413577e+02]
#  [-2.27373675e-13  0.00000000e+00 -7.90113041e+01  5.04294087e+01]]
# [01-08 13:46:47][INFO] Se ajustarán 3 parámetros.
# [01-08 13:46:47][INFO]
# [[ 1.01852593e+02  0.00000000e+00  1.00000000e+01  1.99808900e+02]
#  [ 0.00000000e+00  1.01852593e+02  0.00000000e+00 -1.14413577e+02]
#  [-2.27373675e-13  0.00000000e+00 -7.90113041e+01  5.04294087e+01]]
# [01-08 13:46:47][INFO]
# [[ 1.01852593e+02  0.00000000e+00  1.00000000e+01  1.99808900e+02]
#  [ 0.00000000e+00  1.01852593e+02  0.00000000e+00 -1.14413577e+02]
#  [-2.27373675e-13  0.00000000e+00 -7.90113041e+01  5.04294087e+01]]
# [np.float64(2.024410482925083), np.float64(-1.1233251295755429), np.float64(-0.6382556172537739)]

# %%
x=2.25
a2=2.024410482925083
a1=-1.1233251295755429
a0=-0.6382556172537739

print(a2)
print(a1)
print(a0)
y2= (a2 * x**2 + a1 * x + a0)
print(y2)

x=-2.25
a2=2.024410482925083
a1=-1.1233251295755429
a0=-0.6382556172537739

print(a2)
print(a1)
print(a0)
y2= (a2 * x**2 + a1 * x + a0)
print(y2)
# Out:
# 2.024410482925083
# -1.1233251295755429
# -0.6382556172537739
# 7.082840911009487
# 2.024410482925083
# -1.1233251295755429
# -0.6382556172537739
# 12.13780399409943

# %%
import numpy as np
import matplotlib.pyplot as plt

a,b,c = ajustar_min_cuadrados(xs, ys, gradiente=[der_parcial_0, der_parcial_1 ,der_parcial_2])

x = np.linspace(-5, 5, 100)

y = [a * xi**2 + b * xi + c for xi in x]
plt.scatter(xs1, ys1, label="Datos")
plt.plot(x, y, color="red", label=r"$ y = a_1 x + a_0 $")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste por mínimos cuadrados para conjunto de datos de ejemplo")
plt.legend()
plt.show()
# Out:
# [01-08 13:46:52][INFO] Se ajustarán 3 parámetros.
# [01-08 13:46:52][INFO]
# [[ 1.01852593e+02  0.00000000e+00  1.00000000e+01 -1.17356000e+01]
#  [ 0.00000000e+00  1.01852593e+02  0.00000000e+00  2.09874767e+02]
#  [-2.27373675e-13  0.00000000e+00 -7.90113041e+01  5.33267019e+01]]
# [01-08 13:46:52][INFO]
# [[ 1.01852593e+02  0.00000000e+00  1.00000000e+01 -1.17356000e+01]
#  [ 0.00000000e+00  1.01852593e+02  0.00000000e+00  2.09874767e+02]
#  [-2.27373675e-13  0.00000000e+00 -7.90113041e+01  5.33267019e+01]]

# %% [markdown]
# ## CUBICA

# %%
xs1 = [
    -5.0000,
    -3.8889,
    -2.7778,
    -1.6667,
    -0.5556,
    0.5556,
    1.6667,
    2.7778,
    3.8889,
    5.0000,
]
ys1 = [
    57.2441,
    33.0303,
    16.4817,
    7.0299,
    0.5498,
    0.7117,
    3.4185,
    12.1767,
    24.9167,
    44.2495,
]

# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_3(xs: list, ys: list) -> tuple[float, float, float,float,float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_3=0
    c_2= 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += yi

        c_3 += xi**3
        
        c_2 += xi**2
        # coeficiente del parámetro 1
        c_1 += xi

     # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_3,c_2,c_1, c_0, c_ind)

def der_parcial_2(xs: list, ys: list) -> tuple[float, float, float,float,float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_3=0
    c_2= 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        c_3 += xi**4
        
        c_2 += xi**3
        # coeficiente del parámetro 1
        c_1 += xi**2

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_3,c_2,c_1, c_0, c_ind)

def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float,float,float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_3=0
    c_2= 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += (xi**2) * yi

        c_3 += xi**5
        
        c_2 += xi**4
        # coeficiente del parámetro 1
        c_1 += xi**3

        # coeficiente del parámetro 0
        c_0 += xi**2

    return (c_3,c_2,c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float,float,float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_3=0
    c_2= 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += (xi**3) * yi

        c_3 += xi**6
        
        c_2 += xi**5
        # coeficiente del parámetro 1
        c_1 += xi**4

        # coeficiente del parámetro 0
        c_0 += xi**3

    return (c_3,c_2,c_1, c_0, c_ind)

# %%
from src import ajustar_min_cuadrados  # no modificar esta función

pars = ajustar_min_cuadrados(xs1, ys1, gradiente=[der_parcial_0, der_parcial_1,der_parcial_2,der_parcial_3])
a,b,c,d= ajustar_min_cuadrados(xs1, ys1, gradiente=[der_parcial_0, der_parcial_1,der_parcial_2,der_parcial_3])
print(pars)
# Out:
# [01-08 13:47:01][INFO] Se ajustarán 4 parámetros.
# [01-08 13:47:01][INFO]
# [[1842.14567912    0.          101.8525926     0.         -114.41357678]
#  [   0.         1842.14567912    0.          101.8525926  3664.25103454]
#  [   0.            0.         -321.3553737     0.          219.83127319]
#  [   0.          101.8525926     0.           10.          199.8089    ]]
# [01-08 13:47:01][INFO]
# [[ 1.84214568e+03  0.00000000e+00  1.01852593e+02  0.00000000e+00
#   -1.14413577e+02]
#  [ 0.00000000e+00  1.01852593e+02  0.00000000e+00  1.00000000e+01
#    1.99808900e+02]
#  [ 0.00000000e+00  0.00000000e+00 -3.21355374e+02  0.00000000e+00
#    2.19831273e+02]
#  [ 0.00000000e+00 -2.27373675e-13  0.00000000e+00 -7.90113041e+01
#    5.04294087e+01]]
# [01-08 13:47:01][INFO]
# [[ 1.84214568e+03  0.00000000e+00  1.01852593e+02  0.00000000e+00
#   -1.14413577e+02]
#  [ 0.00000000e+00  1.01852593e+02  0.00000000e+00  1.00000000e+01
#    1.99808900e+02]
#  [ 0.00000000e+00  0.00000000e+00 -3.21355374e+02  0.00000000e+00
#    2.19831273e+02]
#  [ 0.00000000e+00 -2.27373675e-13  0.00000000e+00 -7.90113041e+01
#    5.04294087e+01]]
# [01-08 13:47:01][INFO] Se ajustarán 4 parámetros.
# [01-08 13:47:01][INFO]
# [[1842.14567912    0.          101.8525926     0.         -114.41357678]
#  [   0.         1842.14567912    0.          101.8525926  3664.25103454]
#  [   0.            0.         -321.3553737     0.          219.83127319]
#  [   0.          101.8525926     0.           10.          199.8089    ]]
# [01-08 13:47:01][INFO]
# [[ 1.84214568e+03  0.00000000e+00  1.01852593e+02  0.00000000e+00
#   -1.14413577e+02]
#  [ 0.00000000e+00  1.01852593e+02  0.00000000e+00  1.00000000e+01
#    1.99808900e+02]
#  [ 0.00000000e+00  0.00000000e+00 -3.21355374e+02  0.00000000e+00
#    2.19831273e+02]
#  [ 0.00000000e+00 -2.27373675e-13  0.00000000e+00 -7.90113041e+01
#    5.04294087e+01]]
# [01-08 13:47:01][INFO]
# [[ 1.84214568e+03  0.00000000e+00  1.01852593e+02  0.00000000e+00
#   -1.14413577e+02]
#  [ 0.00000000e+00  1.01852593e+02  0.00000000e+00  1.00000000e+01
#    1.99808900e+02]
#  [ 0.00000000e+00  0.00000000e+00 -3.21355374e+02  0.00000000e+00
#    2.19831273e+02]
#  [ 0.00000000e+00 -2.27373675e-13  0.00000000e+00 -7.90113041e+01
#    5.04294087e+01]]
# [np.float64(-0.024286208523708816), np.float64(2.024410482925083), np.float64(-0.6840752984988344), np.float64(-0.6382556172537739)]

# %%
import numpy as np
import matplotlib.pyplot as plt

a,b,c,d= ajustar_min_cuadrados(xs1, ys1, gradiente=[der_parcial_0, der_parcial_1,der_parcial_2,der_parcial_3])

x = np.linspace(-5, 5, 100)

y = [a * xi**3 + b * xi**2 + c * xi + d for xi in x]

plt.scatter(xs1, ys1, label="Datos")
plt.plot(x, y, color="red", label=r"$ y $")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste por mínimos cuadrados para conjunto de datos de ejemplo")
plt.legend()
plt.show()
# Out:
# [01-08 13:47:03][INFO] Se ajustarán 4 parámetros.
# [01-08 13:47:03][INFO]
# [[1842.14567912    0.          101.8525926     0.         -114.41357678]
#  [   0.         1842.14567912    0.          101.8525926  3664.25103454]
#  [   0.            0.         -321.3553737     0.          219.83127319]
#  [   0.          101.8525926     0.           10.          199.8089    ]]
# [01-08 13:47:03][INFO]
# [[ 1.84214568e+03  0.00000000e+00  1.01852593e+02  0.00000000e+00
#   -1.14413577e+02]
#  [ 0.00000000e+00  1.01852593e+02  0.00000000e+00  1.00000000e+01
#    1.99808900e+02]
#  [ 0.00000000e+00  0.00000000e+00 -3.21355374e+02  0.00000000e+00
#    2.19831273e+02]
#  [ 0.00000000e+00 -2.27373675e-13  0.00000000e+00 -7.90113041e+01
#    5.04294087e+01]]
# [01-08 13:47:03][INFO]
# [[ 1.84214568e+03  0.00000000e+00  1.01852593e+02  0.00000000e+00
#   -1.14413577e+02]
#  [ 0.00000000e+00  1.01852593e+02  0.00000000e+00  1.00000000e+01
#    1.99808900e+02]
#  [ 0.00000000e+00  0.00000000e+00 -3.21355374e+02  0.00000000e+00
#    2.19831273e+02]
#  [ 0.00000000e+00 -2.27373675e-13  0.00000000e+00 -7.90113041e+01
#    5.04294087e+01]]

# %% [markdown]
# ## Expotencial

# %%
from numpy import log

xs1 = [
    -5.0000,
    -3.8889,
    -2.7778,
    -1.6667,
    -0.5556,
    0.5556,
    1.6667,
    2.7778,
    3.8889,
    5.0000,
]
ys1 = [
    57.2441,
    33.0303,
    16.4817,
    7.0299,
    0.5498,
    0.7117,
    3.4185,
    12.1767,
    24.9167,
    44.2495,
]

# Derivadas parciales para regresión lineal
# ####################################################################




def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += log(yi)

        # coeficiente del parámetro 1
        c_1 += xi

        # coeficiente del parámetro 0
        c_0 = len(xs)

    return (c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float,float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    

    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += log(yi)*xi

        # coeficiente del parámetro 1
        c_1 += xi**2

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_1, c_0, c_ind)

# %%
from src import ajustar_min_cuadrados  # no modificar esta función

import numpy as np
import matplotlib.pyplot as plt

pars = ajustar_min_cuadrados(xs1, ys1, gradiente=[der_parcial_0, der_parcial_1])
print(pars)
# Out:
# [01-08 13:53:44][INFO] Se ajustarán 2 parámetros.
# [01-08 13:53:44][INFO]
# [[101.8525926    0.          -4.28278681]
#  [  0.          10.          22.09298203]]
# [np.float64(-0.04204887373505659), np.float64(2.2092982031244675)]

# %%
b=-0.04204887373505659
a=np.exp(2.2092982031244675)
x = np.linspace(-20, 20, 100)

y = [a*np.exp(b*xi) for xi in x]

plt.scatter(xs1, ys1, label="Datos")
plt.plot(x, y, color="red", label=r"$ y $")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste por mínimos cuadrados para conjunto de datos de ejemplo")
plt.legend()
plt.show()

# %% [markdown]
# ## Conjunto de datos 2

# %%
xs2 = [
    0.0003,
    0.0822,
    0.2770,
    0.4212,
    0.4403,
    0.5588,
    0.5943,
    0.6134,
    0.9070,
    1.0367,
    1.1903,
    1.2511,
    1.2519,
    1.2576,
    1.6165,
    1.6761,
    2.0114,
    2.0557,
    2.1610,
    2.6344,
]
ys2 = [
    1.1017,
    1.5021,
    0.3844,
    1.3251,
    1.7206,
    1.9453,
    0.3894,
    0.3328,
    1.2887,
    3.1239,
    2.1778,
    3.1078,
    4.1856,
    3.3640,
    6.0330,
    5.8088,
    10.5890,
    11.5865,
    11.8221,
    26.5077,
]

# %%
plt.scatter(xs2, ys2)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Conjunto de datos 2")
plt.show()

# %% [markdown]
# Interpole el conjunto de datos 2 usando la función exponencial.

# %% [markdown]
# EXPOTENCIAL

# %%
from numpy import log

# Derivadas parciales para regresión lineal
# ####################################################################




def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += log(yi)

        # coeficiente del parámetro 1
        c_1 += xi

        # coeficiente del parámetro 0
        c_0 = len(xs)

    return (c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float,float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    

    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += log(yi)*xi

        # coeficiente del parámetro 1
        c_1 += xi**2

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_1, c_0, c_ind)

# %%
from src import ajustar_min_cuadrados  # no modificar esta función

import numpy as np
import matplotlib.pyplot as plt

pars = ajustar_min_cuadrados(xs2, ys2, gradiente=[der_parcial_0, der_parcial_1])
print(pars)
# Out:
# [01-08 13:57:08][INFO] Se ajustarán 2 parámetros.
# [01-08 13:57:08][INFO]
# [[22.0372     20.         19.05727035]
#  [ 0.         -9.57184451  5.82589171]]
# [np.float64(1.4171603667055432), np.float64(-0.6086488040189696)]

# %%
b=1.4171603667055432
a=np.exp(-0.6086488040189696)
print(a)
x = np.linspace(-5, 5, 100)

y = [a*np.exp(b*xi) for xi in x]

plt.scatter(xs2, ys2, label="Datos")
plt.plot(x, y, color="red", label=r"$ y $")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste por mínimos cuadrados para conjunto de datos de ejemplo")
plt.legend()
plt.show()
# Out:
# 0.5440855388147071

# %%
b=1.4171603667055432
a=np.exp(-0.6086488040189696)
print("a es:")
print(a)
x=5
y = a*np.exp(b*x)
print("y es:")
print(y)

x=1
y = a*np.exp(b*x)
print(y)
# Out:
# a es:
# 0.5440855388147071
# y es:
# 650.1174439111692
# 2.2445646053759503

# %% [markdown]
# ## LINEAL

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """

    # coeficiente del término independiente
    c_ind = sum(ys)

    # coeficiente del parámetro 1
    c_1 = sum(xs)

    # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        # coeficiente del parámetro 1
        c_1 += xi * xi

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_1, c_0, c_ind)
